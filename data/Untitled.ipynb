# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
doc_csv = pd.read_csv('current_mps.csv', sep=';')

# %%
doc_csv
# Out:
#       id                        nom     nom_de_famille     prenom sexe  \
# 0      1             Cédric Roussel            Roussel     Cédric    H
# 1      3  Pascale Fontenel-Personne  Fontenel-Personne    Pascale    F
# 2      5        Guillaume Kasbarian          Kasbarian  Guillaume    H
# 3      6      Cyrille Isaac-Sibille      Isaac-Sibille    Cyrille    H
# 4      7        Guillaume Vuilletet          Vuilletet  Guillaume    H
# ..   ...                        ...                ...        ...  ...
# 569  645          Isabelle Santiago           Santiago   Isabelle    F
# 570  646               Karine Lebon              Lebon     Karine    F
# 571  647              Julien Ravier             Ravier     Julien    H
# 572  648            Grégory Labille            Labille    Grégory    H
# 573  649      Muriel Roques-Etienne     Roques-Etienne     Muriel    F
#
#     date_naissance                      lieu_naissance num_deptmt  \
# ...

# %%
doc_csv.describe()
# Out:
#                id   num_circo  mandat_fin  ancien_depute  \
# count  574.000000  574.000000         0.0          574.0
# mean   320.146341    4.547038         NaN            0.0
# std    186.013566    3.598582         NaN            0.0
# min      1.000000    1.000000         NaN            0.0
# 25%    160.250000    2.000000         NaN            0.0
# 50%    317.500000    3.000000         NaN            0.0
# 75%    482.750000    6.000000         NaN            0.0
# max    649.000000   21.000000         NaN            0.0
#
#        anciens_autres_mandats  place_en_hemicycle          id_an  nb_mandats
# count                     0.0          574.000000     574.000000  574.000000
# mean                      NaN          321.555749  623909.729965    1.264808
# std                       NaN          185.924611  202394.104107    0.464723
# min                       NaN            1.000000     508.000000    1.000000
# ...

# %%
doc_csv.columns
# Out:
# Index(['id', 'nom', 'nom_de_famille', 'prenom', 'sexe', 'date_naissance',
#        'lieu_naissance', 'num_deptmt', 'nom_circo', 'num_circo',
#        'mandat_debut', 'mandat_fin', 'ancien_depute', 'groupe_sigle',
#        'parti_ratt_financier', 'sites_web', 'emails', 'adresses',
#        'collaborateurs', 'autres_mandats', 'anciens_autres_mandats',
#        'anciens_mandats', 'profession', 'place_en_hemicycle', 'url_an',
#        'id_an', 'slug', 'url_nosdeputes', 'url_nosdeputes_api', 'nb_mandats',
#        'twitter'],
#       dtype='object')

# %%
doc_csv.iloc[-1]
# Out:
# id                                                                      649
# nom                                                   Muriel Roques-Etienne
# nom_de_famille                                               Roques-Etienne
# prenom                                                               Muriel
# sexe                                                                      F
# date_naissance                                                   1979-03-05
# lieu_naissance                                                  Albi (Tarn)
# num_deptmt                                                               81
# nom_circo                                                              Tarn
# num_circo                                                                 1
# mandat_debut                                                     2020-10-08
# mandat_fin                                                              NaN
# ...
